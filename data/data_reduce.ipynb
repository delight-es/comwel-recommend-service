# %%
import pandas as pd

df = pd.read_csv('data_reduce.csv')
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#   disease             titles agrees              ids  \
# 0    근골격계            회전근개 파열     인정  2021 판정 제 1871호
# 1    근골격계     방아쇠 손가락 3 ,4수지     인정  2021 판정 제 1869호
# 2    근골격계   고관절 대퇴골두 무혈성 괴사증    불인정  2021 판정 제 1859호
# 3    근골격계    요추4-5번간 ,추간판탈출증    불인정  2021 판정 제 1857호
# 4    근골격계  추간판 탈출증(제4/5 요추간)    불인정  2021 판정 제 1855호
#
#                                               orders  \
# 0  요양급여 신청한 상병“우측 회전근개 파열”은 『산업재해보상보험법』 제37조 제1항 ...
# 1  요양급여 신청 상병 " 방아쇠 손가락 3, 4수지(우측)" 는『산업재해보상보험법』제...
# 2  신청 상병 “우측 고관절 대퇴골두 무혈성 괴사증”은 『산업재해보상보험법』 제37조제...
# 3  신청 상병“요추4-5번간,추간판탈출증”은『산업재해보상보험법』제37조제1항제2호에 의...
# 4  ○ 신청인이 요양급여 신청한 상병 “추간판 탈출증(제4/5 요추간)”은 『산업재해보...
#
#                                              details  \
# 0  ○ 2021년 9월 22일 오전 10시경 ○ 목욕실에서 어르신 목욕을 도와드리는 도...
# 1  ○ 신청인은 ○○○○ ○○점 주방에서 조리를 하기 위해 재료세척 및 손질을 할 때,...
# 2  신청인은 1987년부터 타일공 업무를 시작하여 아파트, 주택 등에서 화장실 바닥, ...
# 3  ○ 신청인은 2021. 9. 5. (이하 주소 생략) 소재 축사 신축공사 현장에서 ...
# ...

# %%
data = pd.read_csv('data_reduce.csv')

data
# Out:
#       Unnamed: 0 disease                                       titles agrees  \
# 0              0    근골격계                                      회전근개 파열     인정
# 1              1    근골격계                               방아쇠 손가락 3 ,4수지     인정
# 2              2    근골격계                             고관절 대퇴골두 무혈성 괴사증    불인정
# 3              3    근골격계                              요추4-5번간 ,추간판탈출증    불인정
# 4              4    근골격계                            추간판 탈출증(제4/5 요추간)    불인정
# ...          ...     ...                                          ...    ...
# 4345        4345    근골격계  외상성으로 명시되지 않은 회전근개 , 극상근 찢김 또는 (완전)(불완전) 파열     인정
# 4346        4346    근골격계                            슬관절반월상연골판후방골기시부파열    불인정
# 4347        4347    근골격계                                        주관증후군    불인정
# 4348        4348    근골격계                              요추부수핵탈출증(L5-S1)     인정
# 4349        4349    근골격계                                       회전근개파열     인정
#
# ...

# %%
df.columns # 열 종류
# Out:
# Index(['disease', 'titles', 'agrees', 'ids', 'orders', 'details', 'opinions',
#        'facts', 'conclusions', 'body', 'new_facts', 'gender', 'death', 'age',
#        'special', 'expert_investigation', 'X_job', 'X_industry', 'Y_job',
#        'Y_industry', 'summarize_conclusions', 'summarize_facts'],
#       dtype='object')

# %%
df['disease'].unique()
count = df[df['disease'] == '뇌심혈관계'].shape[0]
count #뇌심혈관계 개수
# Out:
# 17122

# %%
all_count = df.shape[0]
all_count #전체 개수
# Out:
# 87059

# %%
df_new = df.head(4350) #상위 5%
file_path = 'C:\\Users\\skfmf\\Desktop\\GIT\\comwel-recommend-service\\data\\'
df_new.to_csv(file_path+'data_reduce.csv')
